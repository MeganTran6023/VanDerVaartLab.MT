# %% [markdown]
# ## 1- Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 2- Opening .txt files of RMSD data Major Sequences

# %%
#Block 1 
rmsd_data_b1 = pd.read_csv("rmsd_avg_block1_major.txt", sep=" ", header=None,names=["Sequence", "RMSD Average"])

rmsd_data_b1
# Out:
#       Sequence  RMSD Average
# 0   XTUY/ATTA:       1.15148
# 1   XTUY/ATTC:       1.16115
# 2   XTUY/ATTG:       1.16777
# 3   XTUY/ATTT:       1.12255
# 4   XTUY/CTTA:       1.07918
# 5   XTUY/CTTC:       1.14578
# 6   XTUY/CTTG:       1.22788
# 7   XTUY/CTTT:       1.13791
# 8   XTUY/GTTA:       1.21009
# 9   XTUY/GTTC:       1.18058
# 10  XTUY/GTTG:       1.32332
# 11  XTUY/GTTT:       1.19285
# 12  XTUY/TTTA:       1.14765
# 13  XTUY/TTTC:       1.17013
# 14  XTUY/TTTG:       1.29841
# 15  XTUY/TTTT:       1.19878

# %%
#fix txt file

#1- Remove specific string 'XTUY'
strings_to_remove = ['XTUY/', ':']

#2- loop through each row to see if XTUY and : needs to be removed and does it
for string in strings_to_remove:
    rmsd_data_b1['Sequence'] = rmsd_data_b1['Sequence'].str.replace(string, '')

#3- make new edited file
rmsd_data_b1.to_csv("rmsd_avg_block1_major.txt", sep=' ', index=False)

rmsd_data_b1
# Out:
#    Sequence  RMSD Average
# 0      ATTA       1.15148
# 1      ATTC       1.16115
# 2      ATTG       1.16777
# 3      ATTT       1.12255
# 4      CTTA       1.07918
# 5      CTTC       1.14578
# 6      CTTG       1.22788
# 7      CTTT       1.13791
# 8      GTTA       1.21009
# 9      GTTC       1.18058
# 10     GTTG       1.32332
# 11     GTTT       1.19285
# 12     TTTA       1.14765
# 13     TTTC       1.17013
# 14     TTTG       1.29841
# 15     TTTT       1.19878

# %%
#Block 2 
rmsd_data_b2 = pd.read_csv("rmsd_avg_block2_major.txt", sep=" ", header=None,names=["Sequence", "RMSD Average"])

rmsd_data_b2
# Out:
#       Sequence  RMSD Average
# 0   XTUY/ATTA:       1.08762
# 1   XTUY/ATTC:       1.16125
# 2   XTUY/ATTG:       1.05836
# 3   XTUY/ATTT:       1.01141
# 4   XTUY/CTTA:       1.02276
# 5   XTUY/CTTC:       1.02667
# 6   XTUY/CTTG:       1.06011
# 7   XTUY/CTTT:       1.07476
# 8   XTUY/GTTA:       1.09094
# 9   XTUY/GTTC:       1.02200
# 10  XTUY/GTTG:       1.00500
# 11  XTUY/GTTT:       1.09059
# 12  XTUY/TTTA:       1.00312
# 13  XTUY/TTTC:       1.07801
# 14  XTUY/TTTG:       1.03530
# 15  XTUY/TTTT:       1.17905

# %%
#fix txt file

#1- Remove specific string 'XTUY'
strings_to_remove = ['XTUY/', ':']

#2- loop through each row to see if XTUY and : needs to be removed and does it
for string in strings_to_remove:
    rmsd_data_b2['Sequence'] = rmsd_data_b2['Sequence'].str.replace(string, '')

#3- make new edited file
rmsd_data_b2.to_csv("rmsd_avg_block1_major.txt", sep=' ', index=False)

rmsd_data_b2
# Out:
#    Sequence  RMSD Average
# 0      ATTA       1.08762
# 1      ATTC       1.16125
# 2      ATTG       1.05836
# 3      ATTT       1.01141
# 4      CTTA       1.02276
# 5      CTTC       1.02667
# 6      CTTG       1.06011
# 7      CTTT       1.07476
# 8      GTTA       1.09094
# 9      GTTC       1.02200
# 10     GTTG       1.00500
# 11     GTTT       1.09059
# 12     TTTA       1.00312
# 13     TTTC       1.07801
# 14     TTTG       1.03530
# 15     TTTT       1.17905

# %% [markdown]
# ## 3- Histogram

# %%
#Block 1

import matplotlib.pyplot as plt

rmsd_data_b1['RMSD Average'].plot(kind='hist')

#labels
plt.title("XTUY Major Sequences: RMSD Averages - Block 1")
plt.xlabel("RMSD Averages")

#x-intervals
decimal_int = .1
# x_ticks = np.arange(3.5,3.9,decimal_int)
# plt.xticks(x_ticks)

plt.show()

# %%
#Block 2

import matplotlib.pyplot as plt

rmsd_data_b2['RMSD Average'].plot(kind='hist')

#labels
plt.title("XTUY Major Sequences: RMSD Averages - Block 2")
plt.xlabel("RMSD Averages")

#x-intervals
decimal_int = .1
# x_ticks = np.arange(2.4,3.7,decimal_int)
# plt.xticks(x_ticks)

plt.show()
