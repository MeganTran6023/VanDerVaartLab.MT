# %% [markdown]
# ## 1- Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 2- Opening .txt files of RMSD data Major Sequences

# %%
#Block 1 
rmsd_data_b1 = pd.read_csv("rmsd_avg_block1_major.txt", sep=" ", header=None,names=["Sequence", "RMSD Average"])

rmsd_data_b1
# Out:
#       Sequence  RMSD Average
# 0   XTUY/ATTA:       3.61776
# 1   XTUY/ATTC:       3.62173
# 2   XTUY/ATTG:       3.65273
# 3   XTUY/ATTT:       3.57659
# 4   XTUY/CTTA:       3.54242
# 5   XTUY/CTTC:       3.62355
# 6   XTUY/CTTG:       3.67916
# 7   XTUY/CTTT:       3.58476
# 8   XTUY/GTTA:       3.69307
# 9   XTUY/GTTC:       3.63256
# 10  XTUY/GTTG:       3.78020
# 11  XTUY/GTTT:       3.65868
# 12  XTUY/TTTA:       3.60285
# 13  XTUY/TTTC:       3.62884
# 14  XTUY/TTTG:       3.74815
# 15  XTUY/TTTT:       3.64367

# %%
#fix txt file

#1- Remove specific string 'XTUY'
strings_to_remove = ['XTUY/', ':']

#2- loop through each row to see if XTUY and : needs to be removed and does it
for string in strings_to_remove:
    rmsd_data_b1['Sequence'] = rmsd_data_b1['Sequence'].str.replace(string, '')

#3- make new edited file
rmsd_data_b1.to_csv("rmsd_avg_block1_major.txt", sep=' ', index=False)

rmsd_data_b1
# Out:
#    Sequence  RMSD Average
# 0      ATTA       3.61776
# 1      ATTC       3.62173
# 2      ATTG       3.65273
# 3      ATTT       3.57659
# 4      CTTA       3.54242
# 5      CTTC       3.62355
# 6      CTTG       3.67916
# 7      CTTT       3.58476
# 8      GTTA       3.69307
# 9      GTTC       3.63256
# 10     GTTG       3.78020
# 11     GTTT       3.65868
# 12     TTTA       3.60285
# 13     TTTC       3.62884
# 14     TTTG       3.74815
# 15     TTTT       3.64367

# %%
#Block 2 
rmsd_data_b2 = pd.read_csv("rmsd_avg_block2_major.txt", sep=" ", header=None,names=["Sequence", "RMSD Average"])

rmsd_data_b2
# Out:
#       Sequence  RMSD Average
# 0   XTUY/ATTA:       3.54136
# 1   XTUY/ATTC:       2.39782
# 2   XTUY/ATTG:       3.53323
# 3   XTUY/ATTT:       3.45866
# 4   XTUY/CTTA:       3.48852
# 5   XTUY/CTTC:       3.48272
# 6   XTUY/CTTG:       3.52441
# 7   XTUY/CTTT:       3.54517
# 8   XTUY/GTTA:       3.53727
# 9   XTUY/GTTC:       3.48136
# 10  XTUY/GTTG:       3.47862
# 11  XTUY/GTTT:       3.54849
# 12  XTUY/TTTA:       3.44847
# 13  XTUY/TTTC:       3.52974
# 14  XTUY/TTTG:       3.49456
# 15  XTUY/TTTT:       3.62513

# %%
#fix txt file

#1- Remove specific string 'XTUY'
strings_to_remove = ['XTUY/', ':']

#2- loop through each row to see if XTUY and : needs to be removed and does it
for string in strings_to_remove:
    rmsd_data_b2['Sequence'] = rmsd_data_b2['Sequence'].str.replace(string, '')

#3- make new edited file
rmsd_data_b2.to_csv("rmsd_avg_block1_major.txt", sep=' ', index=False)

rmsd_data_b2
# Out:
#    Sequence  RMSD Average
# 0      ATTA       3.54136
# 1      ATTC       2.39782
# 2      ATTG       3.53323
# 3      ATTT       3.45866
# 4      CTTA       3.48852
# 5      CTTC       3.48272
# 6      CTTG       3.52441
# 7      CTTT       3.54517
# 8      GTTA       3.53727
# 9      GTTC       3.48136
# 10     GTTG       3.47862
# 11     GTTT       3.54849
# 12     TTTA       3.44847
# 13     TTTC       3.52974
# 14     TTTG       3.49456
# 15     TTTT       3.62513

# %% [markdown]
# ## 3- Histogram

# %%
#Block 1

import matplotlib.pyplot as plt

rmsd_data_b1['RMSD Average'].plot(kind='hist')

#labels
plt.title("XTUY Major Sequences: RMSD Averages - Block 1")
plt.xlabel("RMSD Averages")

#x-intervals
decimal_int = .1
x_ticks = np.arange(3.5,3.9,decimal_int)
plt.xticks(x_ticks)

plt.show()

# %%
#Block 2

import matplotlib.pyplot as plt

rmsd_data_b2['RMSD Average'].plot(kind='hist')

#labels
plt.title("XTUY Major Sequences: RMSD Averages - Block 2")
plt.xlabel("RMSD Averages")

#x-intervals
decimal_int = .1
x_ticks = np.arange(2.4,3.7,decimal_int)
plt.xticks(x_ticks)

plt.show()
