# %% [markdown]
# ## 1- Import CSV

# %%
# #All data

# import pandas as pd

# input_file = pd.read_csv("XTUY_Histogram.csv")

# #removes sequences without any register shifts
# input_file.dropna()
# Out:
#      Sequences  How long RS last? (frames)  Start time (frames)  \
# 0   ATTA-minor                          23                  217
# 1         ATTC                         190                  890
# 3         ATTT                       17349                 2651
# 4         ATTT                         604                  479
# 5   ATTT-minor                       19417                  583
# 7   GTTT-minor                       35663                 4337
# 8   GTTT-minor                         385                 1368
# 9   GTTT-minor                        2329                 1754
# 10        TTTT                       19251                  749
# 11  CTTA-minor                       37174                 2826
# 12  CTTA-minor                         327                 1691
# 13  CTTA-minor                          57                 1532
# 14  CTTT-minor                        1101                 8383
# 15  CTTT-minor                        4073                 9484
# ...

# %%
#Uracil Major Flip
import pandas as pd

input_major = pd.read_csv("GC_XTUY_major.csv")

#removes sequences without any register shifts
input_major.dropna()
# Out:
#   Sequences  How long RS last? (ns) What base (below/above)
# 0      CTCC                   12490             C-A (above)
# 1      TTCT                   16690               T-A above
# 2      CTCC                     210             C-A (above)
# 3      CTCC                    9750             C-A (above)
# 4      CTCC                     240             C-A (above)
# 5      CTCC                     710             C-A (above)

# %%
# #Uracil Minor Flip

# input_minor = pd.read_csv("XTUY_minor.csv")

# #removes sequences without any register shifts
# input_minor.dropna()
# Out:
#      Sequences  How long RS last? (frames)  Start time (frames)  \
# 0   ATTA-minor                          23                  217
# 2   ATTT-minor                       19417                  583
# 4   GTTT-minor                       35663                 4337
# 5   GTTT-minor                         385                 1368
# 6   GTTT-minor                        2329                 1754
# 7   CTTA-minor                       37174                 2826
# 8   CTTA-minor                         327                 1691
# 9   CTTA-minor                          57                 1532
# 10  CTTT-minor                        1101                 8383
# 11  CTTT-minor                        4073                 9484
# 13  CTTC-minor                        2152                 1408
# 14  CTTC-minor                        3225                 3695
# 15  CTTC-minor                         380                 7735
# 17  GTTC-minor                         107                12197
# ...

# %% [markdown]
# ## 2- Make Histogram

# %% [markdown]
# ### 2a) Histogram for register shift (RS) duration

# %%
# import matplotlib.pyplot as plt

# input_file['How long RS last? (frames)'].plot(kind='hist')

# #labels
# plt.title("XTUY Sequences: Frequency of Register Shifts")
# plt.xlabel("Register Shift Duration (frames)")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 import matplotlib.pyplot as plt
# ----> 3 input_file['How long RS last? (frames)'].plot(kind='hist')
#       5 #labels
#       6 plt.title("XTUY Sequences: Frequency of Register Shifts")
#
# NameError: name 'input_file' is not defined

# %% [markdown]
# ### 2b) Histogram Major flip

# %%
import matplotlib.pyplot as plt

input_major['How long RS last? (ns)'].plot(kind='hist',bins=15)

#labels
plt.title("GC XTUY Major Sequences: Frequency of Register Shifts")
plt.xlabel("Register Shift Duration (ns)")
# Out:
# Text(0.5, 0, 'Register Shift Duration (ns)')

# %% [markdown]
# ### 2c) Histogram Minor Flip

# %%
# import matplotlib.pyplot as plt

# input_minor['How long RS last? (frames)'].plot(kind='hist',bins=15)

# #labels
# plt.title("XTUY Minor Sequences: Frequency of Register Shifts")
# plt.xlabel("Register Shift Duration (frames)")
# Out:
# Text(0.5, 0, 'Register Shift Duration (frames)')
